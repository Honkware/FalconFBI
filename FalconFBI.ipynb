# %% [markdown]
# <a href="https://colab.research.google.com/github/Honkware/FalconFBI/blob/main/FalconFBI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install httpx beautifulsoup4 pandas nltk torch transformers auto-gptq einops

# %%
import logging
import os
import sys
from functools import partial
from multiprocessing import Pool

import httpx
import pandas as pd
from IPython.display import display, HTML

import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import torch
from transformers import AutoTokenizer
from auto_gptq import AutoGPTQForCausalLM

from bs4 import BeautifulSoup

from tqdm.notebook import tqdm

nltk.download('stopwords')

base_url = 'https://www.fbi.gov/'
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Scraping

def get_individual_data(url):
    try:
        if url.startswith('/'):
            url = base_url + url
        soup = BeautifulSoup(httpx.get(url).text, 'html.parser')
        name = soup.select_one('.documentFirstHeading').text.split('\n')[0].strip()
        aliases = (
            soup.select_one('.wanted-person-aliases p').text.strip()
            if (aliases := soup.select_one('.wanted-person-aliases'))
            else ''
        )
        reward = (
            soup.select_one('.wanted-person-reward p').text.strip()
            if (reward := soup.select_one('.wanted-person-reward'))
            else ''
        )
        remarks = (
            soup.select_one('.wanted-person-remarks p').text.strip()
            if (remarks := soup.select_one('.wanted-person-remarks'))
            else ''
        )
        caution = (
            soup.select_one('.wanted-person-caution p').text.strip()
            if (caution := soup.select_one('.wanted-person-caution'))
            else ''
        )
        image_url = soup.select_one(".wanted-person-mug img")["src"]
        image_link = f'<a href="{url}" target="_blank"><img src="{image_url}" width="50px"></a>'

        return {
            'Name': f'<a href="{url}" target="_blank">{name}</a>',
            'Image': image_link,
            'Aliases': aliases,
            'Reward': reward,
            'Remarks': remarks,
            'Caution': caution,
        }
    except Exception as e:
        logging.error(f"Error occurred while scraping individual data: {str(e)}")
        return {
            'Name': '',
            'Image': '',
            'Aliases': '',
            'Reward': '',
            'Remarks': '',
            'Caution': '',
        }


def scrape_individuals():
    try:
        soup = BeautifulSoup(httpx.get(f'{base_url}/wanted/topten').text, 'html.parser')
        individual_urls = [a['href'] if a['href'].startswith('/') else a['href'] for a in soup.select('.portal-type-person .title a')]

        with Pool() as pool:
            return list(pool.map(get_individual_data, individual_urls))
    except Exception as e:
        logging.error(f"Error occurred while scraping individuals: {str(e)}")
        return []


df = pd.DataFrame(scrape_individuals())
df = df[['Name', 'Image', 'Aliases', 'Reward', 'Remarks', 'Caution']]

# %%
# Generation

nltk.download('stopwords')

stopwords_set = set(stopwords.words('english'))
stemmer = PorterStemmer()

nltk_logger = logging.getLogger('nltk')
nltk_logger.setLevel(logging.ERROR)

quantized_model_dir = "TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ"
tokenizer = AutoTokenizer.from_pretrained(quantized_model_dir, use_fast=False)
model = AutoGPTQForCausalLM.from_quantized(
    quantized_model_dir,
    device="cuda:0",
    use_triton=False,
    use_safetensors=True,
    torch_dtype=torch.float32,
    trust_remote_code=True
)


def preprocess_row(row):
    remarks = row['Remarks']
    aliases = row['Aliases']
    reward = row['Reward']
    caution = row['Caution']

    filtered_words = [stemmer.stem(word.lower()) for word in remarks.split() if word.lower() not in stopwords_set]
    filtered_remarks = ' '.join(filtered_words)

    filtered_aliases = ' '.join([word for word in aliases.split() if word.lower() not in stopwords_set])

    filtered_words = [stemmer.stem(word.lower()) for word in reward.split() if word.lower() not in stopwords_set]
    filtered_reward = ' '.join(filtered_words)

    filtered_words = [stemmer.stem(word.lower()) for word in caution.split() if word.lower() not in stopwords_set]
    filtered_caution = ' '.join(filtered_words)

    return filtered_remarks, filtered_aliases, filtered_reward, filtered_caution, row['Image']


def generate_reports(df):
    logging.getLogger().setLevel(logging.WARNING)

    preprocessed_rows = [preprocess_row(row) for _, row in tqdm(df.iterrows(), total=len(df), desc="Preprocessing")]

    reports = []
    with tqdm(total=len(df), desc="Generating Reports", bar_format='{l_bar}{bar}| {n_fmt}/{total_fmt}') as pbar:
        for preprocessed_row, row in zip(preprocessed_rows, df.itertuples()):
            report_html = generate_report(tokenizer, model, preprocessed_row, row)
            reports.append(report_html)
            display(HTML(report_html))
            pbar.update(1)

    return reports

def generate_report(tokenizer, model, preprocessed_row, row):
    remarks, aliases, reward, caution, image_url = preprocessed_row

    # Construct the person string
    if aliases:
        person = f"{aliases} ({row.Name})"
    else:
        person = row.Name

    # Handle missing fields
    reward = reward if reward else ''
    remarks = remarks if remarks else ''
    caution = caution if caution else ''

    text_inputs = f"## SUSPECT INFO:{person}\n{remarks}\n{reward}\n{caution}\n## SUMMARY:"
    encoding = tokenizer.encode_plus(
        text_inputs,
        max_length=512,
        truncation=True,
        padding="longest",
        return_tensors="pt"
    )
    input_ids = encoding["input_ids"].to("cuda:0")
    attention_mask = encoding["attention_mask"].to("cuda:0")
    with torch.no_grad():
        output = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            eos_token_id=tokenizer.eos_token_id,
            max_length=512,
            do_sample=True,
            temperature=0.8,
            pad_token_id=tokenizer.eos_token_id
        )
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    summary_start = "## SUMMARY:"
    generated_text = generated_text[generated_text.index(summary_start) + len(summary_start):].strip()

    report_html = f"""
    <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
        <div>
            <a href="{base_url}/most-wanted/{aliases.lower().replace(' ', '-')}" target="_blank">
            {image_url}
            </a>
            <h3>{person}</h3>
        </div>
        <p><strong>Generated Report:</strong></p>
        <p>{generated_text}</p>
        <div style="clear: both;"></div>
    </div>
    """

    return report_html

reports = generate_reports(df)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# WARNING:accelerate.utils.modeling:The safetensors archive passed at /root/.cache/huggingface/hub/models--TheBloke--WizardLM-Uncensored-Falcon-7B-GPTQ/snapshots/d8a0cebfa7f259dffd4e50d3a9b83450a4756084/gptq_model-4bit-64g.safetensors does not contain metadata. Make sure to save your model with the `save_pretrained` method. Defaulting to 'pt' metadata.
# WARNING:auto_gptq.modeling._base:can't get model's sequence length from model config, will set to 4096.
# WARNING:auto_gptq.modeling._base:RWGPTQForCausalLM hasn't fused attention module yet, will skip inject fused attention.
# WARNING:auto_gptq.modeling._base:RWGPTQForCausalLM hasn't fused mlp module yet, will skip inject fused mlp.
# Preprocessing:   0%|          | 0/10 [00:00<?, ?it/s]
# Generating Reports:   0%|          | 0/10
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/dr.-ruja-ignatova,-ruja-plamenova-ignatova,-ruja-p.-ignatova,-"cryptoqueen"" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/ruja-ignatova" target="_blank"><img src="https://www.fbi.gov/wanted/topten/ruja-ignatova/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>Dr. Ruja Ignatova, Ruja Plamenova Ignatova, Ruja P. Ignatova, "CryptoQueen" (<a href="https://www.fbi.gov/wanted/topten/ruja-ignatova" target="_blank">RUJA IGNATOVA</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>Ruja Ignatova is a Bulgarian-American entrepreneur and self-proclaimed "CryptoQueen" who is wanted by the FBI for her alleged involvement in a large-scale fraud scheme. The FBI believes that Ignatova and her associates have defrauded billions of dollars from investors around the world through the fraudulent sale of OneCoin, a digital currency. Ignatova has been known to use aliases such as Ruja Plamenova Ignatova and Ruja P. Ignatova, and may have undergone plastic surgery to alter her appearance. The FBI is offering a $250,000 reward for information leading to her arrest.</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/fields,-donald-eugene-fields-jr.,-eugene-fields" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/donald-eugene-fields-ii" target="_blank"><img src="https://www.fbi.gov/wanted/topten/donald-eugene-fields-ii/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>Fields, Donald Eugene Fields Jr., Eugene Fields (<a href="https://www.fbi.gov/wanted/topten/donald-eugene-fields-ii" target="_blank">DONALD EUGENE FIELDS II</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>Donald Eugene Fields Jr., also known as Donald Fields, is wanted by the FBI for sex trafficking of minors. Fields is believed to be in the Missouri area. He is believed to have recruited, enticed, or otherwise lured at least one child to engage in sex acts for the purpose of commercial sex or for sex tourism. Fields is believed to be from Kentucky and may have connections to Florida. He has been known to visit casinos in Florida in the past. Fields is being offered a reward of up to $250,000 for his arrest. He is believed to be between 35 and 45 years old and is known to have black hair and brown eyes. Fields is known to be a heavy set male with a large build. Anyone with information on Fields' whereabouts is urged to contact the FBI or local law enforcement.</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/arnoldo-gimenez,-arnoldo-rochel-jimenez" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/arnoldo-jimenez" target="_blank"><img src="https://www.fbi.gov/wanted/topten/arnoldo-jimenez/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>Arnoldo Gimenez, Arnoldo Rochel Jimenez (<a href="https://www.fbi.gov/wanted/topten/arnoldo-jimenez" target="_blank">ARNOLDO JIMENEZ</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>Arnoldo Gimenez, also known as "Jimmy" or "Little Jimmy," is wanted by the FBI for allegedly killing his wife, and may also be involved in other criminal activities. He is believed to be hiding out in the Reynosa area of Mexico, and may also frequent the Tamaulipas region. The FBI has offered a $250,000 reward for anyone who provides information leading to his arrest.</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/omar-alexander-cardenas" target="_blank"><img src="https://www.fbi.gov/wanted/topten/omar-alexander-cardenas/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3><a href="https://www.fbi.gov/wanted/topten/omar-alexander-cardenas" target="_blank">OMAR ALEXANDER CARDENAS</a></h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>Omar Alexander Cardenas is wanted by the Federal Bureau of Investigation (FBI) for murder and is offering a reward of $250,000 for his arrest. In August 2019, Cardenas is alleged to have opened fire at a large outdoor shop center in Sylmar, California, and struck a victim with a semi-automatic handgun, causing death. On April 3, 2020, a local arrest warrant was issued for Cardenas, and a subsequent federal arrest warrant was issued on September 2, 2021. Cardenas is believed to be in the Central District of California, and the FBI is offering a reward of up to $250,000 for his arrest.</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/mario-flores,-mario-roberto-flores,-mario-f.-roberto,-alex-contreras,-alesis-contreras" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/alexis-flores" target="_blank"><img src="https://www.fbi.gov/wanted/topten/alexis-flores/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>Mario Flores, Mario Roberto Flores, Mario F. Roberto, Alex Contreras, Alesis Contreras (<a href="https://www.fbi.gov/wanted/topten/alexis-flores" target="_blank">ALEXIS FLORES</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>ALEXIS FLORES is wanted for kidnap and murder charges in the United States. He is believed to be living in Honduras.
# The FBI is offering a reward of $250,000 for information leading to his arrest.
# Alexi Flores is wanted in the case of a missing five-year-old girl who was kidnapped and murdered in Philadelphia, Pennsylvania. Her body was later found strangled near a bi-state bridge. The case was opened in 2000.
# If you have any information about Alexi Flores or this case, please contact the FBI at 1-800-CALL-FBI (1-800-225-5324).</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/alexander-mendoza,-yulan-andony-archaga-carias,-“porky”" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/yulan-adonay-archaga-carias" target="_blank"><img src="https://www.fbi.gov/wanted/topten/yulan-adonay-archaga-carias/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>Alexander Mendoza, Yulan Andony Archaga Carias, “Porky” (<a href="https://www.fbi.gov/wanted/topten/yulan-adonay-archaga-carias" target="_blank">YULAN ADONAY ARCHAGA CARIAS</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>Alexander Mendoza and Yulan Archaga Carias are wanted for their involvement in a drug trafficking organization that operates in Honduras and the United States. Mendoza is believed to be the leader of the organization and is wanted for racketeering and drug trafficking charges. Archaga Carias is also believed to be involved in the organization and is wanted for weapons possession and money laundering charges. The FBI is offering a reward of $5,000,000 for information leading to the arrest and conviction of these individuals.</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/bhadreshkumar-c.-patel" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/bhadreshkumar-chetanbhai-patel" target="_blank"><img src="https://www.fbi.gov/wanted/topten/bhadreshkumar-chetanbhai-patel/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>Bhadreshkumar C. Patel (<a href="https://www.fbi.gov/wanted/topten/bhadreshkumar-chetanbhai-patel" target="_blank">BHADRESHKUMAR CHETANBHAI PATEL</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>Bhadresh Patel is wanted by the FBI for the alleged murder of his wife in Maryland on April 12, 2015. He is also being sought for other crimes, including attempted murder and assault with a deadly weapon in the same state. A reward of $250,000 is being offered for information leading to his arrest.</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/carlos-el-puerco,-el-puerco,-wilver-villegas,-wilver-palomino" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/wilver-villegas-palomino" target="_blank"><img src="https://www.fbi.gov/wanted/topten/wilver-villegas-palomino/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>Carlos El Puerco, El Puerco, Wilver Villegas, Wilver Palomino (<a href="https://www.fbi.gov/wanted/topten/wilver-villegas-palomino" target="_blank">WILVER VILLEGAS-PALOMINO</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>Carlos El Puerco, El Puerco, Wilver Villegas, and Wilver Palomino are wanted for their suspected involvement in drug trafficking and terrorism in the Catatumbo region of Colombia, Venezuela, and the United States. The FBI has issued a warrant for the arrest of Villegas-Palomino. A reward of $5 million is available for information leading to his arrest or conviction.</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/alexandro-castillo,-alex-castillo,-alejandro-rosales,-alejandro-castillo,-alejandro-rosales-castillo,-alejandro-rosalescastillo" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/alejandro-castillo" target="_blank"><img src="https://www.fbi.gov/wanted/topten/alejandro-castillo/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>Alexandro Castillo, Alex Castillo, Alejandro Rosales, Alejandro Castillo, Alejandro Rosales-Castillo, Alejandro Rosalescastillo (<a href="https://www.fbi.gov/wanted/topten/alejandro-castillo" target="_blank">ALEJANDRO ROSALES CASTILLO</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>Alejandro Rosales-Castillo is a suspect wanted by the FBI for his alleged involvement in a 2016 murder case in North Carolina. He is wanted for the murder of a female victim in Phoenix, Arizona, on August 15, 2016. His last known residence is in Charlotte, North Carolina, and he may cross the Mexican border to San Francisco de Lo Río, Aguascalientes, Pabellón de Arteaga, and Aguascalientes. Authorities are offering a $250,000 reward for information leading to his arrest.</p>
#         <div style="clear: both;"></div>
#     </div>
#     <div style="border: 1px solid black; padding: 10px; margin-bottom: 20px;">
#         <div>
#             <a href="https://www.fbi.gov//most-wanted/"el-gato"" target="_blank">
#             <a href="https://www.fbi.gov/wanted/topten/jose-rodolfo-villarreal-hernandez" target="_blank"><img src="https://www.fbi.gov/wanted/topten/jose-rodolfo-villarreal-hernandez/@@images/image/preview" width="50px"></a>
#             </a>
#             <h3>"El Gato" (<a href="https://www.fbi.gov/wanted/topten/jose-rodolfo-villarreal-hernandez" target="_blank">JOSE RODOLFO VILLARREAL-HERNANDEZ</a>)</h3>
#         </div>
#         <p><strong>Generated Report:</strong></p>
#         <p>JOSE RODOLFO VILLARRE-HERNANDEZ is wanted by the FBI for his alleged involvement in a murder-for-hire conspiracy. He is believed to be living in Monterrey, Mexico, or Mexico City, Mexico. The FBI is offering a reward of up to $1 million for information leading directly to his arrest.</p>
#         <div style="clear: both;"></div>
#     </div>
